# %%
# 1. INSTALACIÓN DE LIBRERÍAS
# Instalamos YOLOv8 (ultralytics) y Roboflow
# %pip install ultralytics roboflow

from ultralytics import YOLO
from roboflow import Roboflow
import os

# 2. DESCARGA DEL DATASET (Tu código)
rf = Roboflow(api_key="QGWKCt06VkGb81LIyLHV")
project = rf.workspace("yolo-lt96t").project("construction-equipment-6r96y-h5vko")
version = project.version(1)
dataset = version.download("yolov8")

# 3. ENTRENAMIENTO
# Usamos 'yolov8n.pt' (Nano) porque es el más rápido para Android
print("🚀 Iniciando entrenamiento...")
model = YOLO('yolov8n.pt')

# Entrenamos por 25 épocas (suficiente para el examen)
# imgsz=640 es el estándar
results = model.train(data=f"{dataset.location}/data.yaml", epochs=25, imgsz=640)

# 4. EXPORTACIÓN A ONNX
print("📦 Exportando modelo a ONNX para Android...")
# dynamic=False y opset=12 aseguran compatibilidad con C++ nativo
path = model.export(format='onnx', dynamic=False, opset=12)

print(f"✅ ¡LISTO! Tu archivo está en: {path}")
print("---------------------------------------------------------")
print("⚠️ COPIA ESTAS CLASES PARA TU MAINACTIVITY.KT:")
print(model.names)
print("---------------------------------------------------------")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 93.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 109.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...
